# %%
import os
import sys
sys.path.append('D:/ML/Kis_Api_test/1_DB_System/')

# %%
from communication import StockConnection, DB_Handle
import datetime
import pandas as pd
from queue import Queue

# %%
def date_to_string(date:datetime.date):
    conv_date = str(date)
    return conv_date[:4] + conv_date[5:7] + conv_date[-2:]

# %%
sc = StockConnection()
db = DB_Handle(db_name='db_for_test')
que = Queue()
# Out:
# good

# %%
kospi = pd.read_csv('../../4_SRC/current_kospi_codes.csv')
kospi['종목코드'] = kospi['종목코드'].apply(lambda x : str(x).zfill(6))

# %%
kosdaq = pd.read_csv('../../4_SRC/current_kosdaq_codes.csv')
kosdaq['종목코드'] = kosdaq['종목코드'].apply(lambda x : str(x).zfill(6))

# %%
def result_handle(tr):
    global que
    try:
        for idx, res in enumerate(tr['output2'][::-1]):
            buf = []
            buf.append(tr['output1']['stck_shrn_iscd'])
            buf.append(res['stck_bsop_date'])
            buf.append(res['stck_clpr'])
            buf.append(res['stck_oprc'])
            buf.append(res['stck_hgpr'])
            buf.append(res['stck_lwpr'])
            buf.append(res['acml_vol'])
            buf.append(res['acml_tr_pbmn'])
            que.put(buf)
    except:     
        pass

# %%
for idx, context in kospi.iterrows():
    if context['회사명'] == '삼성전자':
        first_y, first_m, first_d = context['상장일'].split('-')
        first_date = datetime.date(int(first_y), int(first_m), int(first_d))
        start = datetime.date(2021, 11 ,18)#first_date
        end = start + datetime.timedelta(99)
        while end <= datetime.date.today():
            result = sc.date_price(no=context['종목코드'], 
                                   start=date_to_string(start), 
                                   end=date_to_string(end), 
                                   period='D')
            for idx, res in enumerate(result['output2'][::-1]):
                try:
                    buf = []
                    buf.append(result['output1']['stck_shrn_iscd'])
                    buf.append(res['stck_bsop_date'])
                    buf.append(res['stck_clpr'])
                    buf.append(res['stck_oprc'])
                    buf.append(res['stck_hgpr'])
                    buf.append(res['stck_lwpr'])
                    buf.append(res['acml_vol'])
                    buf.append(res['acml_tr_pbmn'])
#                     db.fetch(table_name='test', telegram=buf)
                    sql = f'INSERT INTO test {db.COLUMNS} VALUES (%s, %s, %s, %s, %s, %s, %s, %s)'
                    db.CUR.excute(sql, telegram)
                except:
                    pass
            print(f'st:{start}, end:{end}')
            start = end + datetime.timedelta(1)
            end = start + datetime.timedelta(99)
        result = sc.date_price(no=context['종목코드'], 
                                   start=date_to_string(start), 
                                   end=date_to_string(datetime.date.today()), 
                                   period='D')
        try:
            for idx, res in enumerate(result['output2'][::-1]):
                buf = []
                buf.append(result['output1']['stck_shrn_iscd'])
                buf.append(res['stck_bsop_date'])
                buf.append(res['stck_clpr'])
                buf.append(res['stck_oprc'])
                buf.append(res['stck_hgpr'])
                buf.append(res['stck_lwpr'])
                buf.append(res['acml_vol'])
                buf.append(res['acml_tr_pbmn'])
                db.fetch(table_name='test', telegram=buf)
        except:
            pass
    
    else:
        pass
db.commit()
# Out:
# ['005930', '20211118', '70200', '70700', '71000', '70200', '10144957', '715155784712']
# ['005930', '20211119', '71200', '70400', '71400', '70100', '11954728', '844715736500']
# ['005930', '20211122', '74900', '73300', '75200', '73000', '27506624', '2047227974600']
# ['005930', '20211123', '75300', '76000', '76000', '74500', '22029196', '1656722300700']
# ['005930', '20211124', '74800', '76000', '76200', '74100', '15652305', '1174195612600']
# ['005930', '20211125', '73700', '75100', '75100', '73600', '12559258', '929571252060']
# ['005930', '20211126', '72300', '73500', '74100', '72000', '13002242', '944377957159']
# ['005930', '20211129', '72300', '71700', '73000', '71400', '16682559', '1206605509200']
# ['005930', '20211130', '71300', '73200', '73900', '70500', '30364840', '2183677859000']
# ['005930', '20211201', '74400', '72000', '74800', '71600', '21954856', '1610884710200']
# ['005930', '20211202', '75800', '73900', '75800', '73800', '23652940', '1778784775812']
# ['005930', '20211203', '75600', '75600', '76000', '74100', '18330240', '1375860953642']
# ['005930', '20211206', '76300', '75100', '76700', '74900', '16391250', '1245309081800']
# ['005930', '20211207', '77400', '76100', '77700', '75600', '19232452', '1477888023100']
# ['005930', '20211208', '77400', '78300', '78600', '77100', '21558340', '1662978972800']
# ['005930', '20211209', '78200', '77400', '78200', '77000', '21604528', '1681184112100']
# ['005930', '20211210', '76900', '77400', '77600', '76800', '9155219', '705966272740']
# ['005930', '20211213', '76800', '77200', '78300', '76500', '15038750', '1163285000550']
# ['005930', '20211214', '77000', '76500', '77200', '76200', '10976660', '841446671988']
# ['005930', '20211215', '77600', '76400', '77600', '76300', '9584939', '738591816100']
# ['005930', '20211216', '77800', '78500', '78500', '77400', '11996128', '934244160164']
# ['005930', '20211217', '78000', '76800', '78000', '76800', '13108479', '1016846497195']
# ['005930', '20211220', '77100', '77600', '77800', '76800', '11264375', '869972000855']
# ['005930', '20211221', '78100', '77900', '78300', '77500', '14245298', '1110658660990']
# ['005930', '20211222', '79400', '78900', '79400', '78800', '17105892', '1354311131000']
# ['005930', '20211223', '79900', '79800', '80000', '79300', '13577498', '1083055928000']
# ['005930', '20211224', '80500', '80200', '80800', '80200', '12086380', '973661791400']
# ['005930', '20211227', '80200', '80600', '80600', '79800', '10783368', '864327041000']
# ['005930', '20211228', '80300', '80200', '80400', '79700', '18226324', '1458198874200']
# ['005930', '20211229', '78800', '80200', '80200', '78500', '19794796', '1569040228400']
# ['005930', '20211230', '78300', '78900', '79500', '78100', '14236700', '1120743115800']
# ['005930', '20220103', '78600', '79400', '79800', '78200', '13502112', '1066006837750']
# ['005930', '20220104', '78700', '78800', '79200', '78300', '12427416', '977990613000']
# ['005930', '20220105', '77400', '78800', '79000', '76400', '25470640', '1967841509800']
# ['005930', '20220106', '76900', '76700', '77600', '76600', '12931954', '996378432570']
# ['005930', '20220107', '78300', '78100', '78400', '77400', '15163757', '1184236552700']
# ['005930', '20220110', '78000', '78100', '78100', '77100', '9947422', '772740467800']
# ['005930', '20220111', '78900', '78400', '79000', '78000', '13221123', '1038834579600']
# ['005930', '20220112', '78900', '79500', '79600', '78600', '11000502', '868910854000']
# ['005930', '20220113', '77900', '79300', '79300', '77900', '13889401', '1088598373464']
# ['005930', '20220114', '77300', '77700', '78100', '77100', '10096725', '781574668408']
# ['005930', '20220117', '77500', '77600', '77800', '76900', '8785122', '678903113900']
# ['005930', '20220118', '77000', '77600', '77800', '76600', '9592788', '740278857400']
# ['005930', '20220119', '76300', '76500', '76900', '76100', '10598290', '810150634900']
# ['005930', '20220120', '76500', '76200', '76700', '75900', '9708168', '741154141302']
# ['005930', '20220121', '75600', '75800', '75800', '74700', '15774888', '1186292783000']
# ['005930', '20220124', '75100', '75400', '75800', '74700', '13691134', '1028859496700']
# ['005930', '20220125', '74000', '74800', '75000', '73200', '17766704', '1313117613328']
# ['005930', '20220126', '73300', '73900', '74400', '73100', '12976730', '955547183400']
# ['005930', '20220127', '71300', '73800', '74000', '71300', '22274776', '1603685111200']
# ['005930', '20220128', '73300', '71300', '73700', '71200', '21367448', '1552585967650']
# ['005930', '20220203', '73300', '74900', '74900', '73300', '17744720', '1314506070081']
# ['005930', '20220204', '74000', '74300', '74600', '73400', '12730034', '941413120563']
# ['005930', '20220207', '73000', '73500', '73600', '72400', '14240838', '1037300433232']
# ['005930', '20220208', '73500', '73800', '74200', '73000', '11736666', '863666435400']
# ['005930', '20220209', '74700', '74300', '74700', '74000', '9699122', '722221184750']
# ['005930', '20220210', '75400', '75600', '75800', '74700', '17746032', '1337516647000']
# ['005930', '20220211', '74900', '75000', '75500', '74600', '12205407', '915455022610']
# ['005930', '20220214', '73700', '74400', '74500', '73100', '13993255', '1030683563200']
# ['005930', '20220215', '73700', '74100', '74200', '73100', '9320365', '686706909200']
# ['005930', '20220216', '74800', '74600', '74900', '74200', '10767386', '802448854700']
# ['005930', '20220217', '75000', '75000', '75600', '74500', '13605382', '1021980123500']
# ['005930', '20220218', '74300', '74600', '74800', '73700', '10122226', '751583038400']
# ['005930', '20220221', '74200', '73200', '74300', '72600', '10489717', '769773939300']
# ['005930', '20220222', '73400', '73000', '73400', '72800', '11692469', '854469006291']
# ['005930', '20220223', '73000', '73800', '73800', '72800', '10397964', '759964784500']
# ['005930', '20220224', '71500', '72300', '72300', '71300', '15759283', '1130166428800']
# ['005930', '20220225', '71900', '72100', '72600', '71900', '13168484', '950762004400']
# st:2021-11-18, end:2022-02-25
# ['005930', '20220228', '72100', '71100', '72100', '71000', '17781784', '1272250751300']
# ['005930', '20220302', '71700', '72300', '72400', '71500', '12481430', '897368743880']
# ['005930', '20220303', '72900', '72300', '73100', '72200', '13232638', '962676478940']
# ['005930', '20220304', '71500', '72700', '72700', '71200', '13409634', '960572417800']
# ['005930', '20220307', '70100', '70000', '70600', '69900', '18617138', '1305288850400']
# ['005930', '20220308', '69500', '68800', '70000', '68700', '15828269', '1100279437100']
# ['005930', '20220310', '71200', '70800', '71200', '70500', '21159248', '1500935516076']
# ['005930', '20220311', '70000', '70500', '70700', '69700', '15787655', '1105586321900']
# ['005930', '20220314', '70200', '70000', '70200', '69600', '9040993', '632752468500']
# ['005930', '20220315', '69500', '69800', '70100', '69500', '10258562', '715550312992']
# ['005930', '20220316', '70400', '70200', '70500', '69700', '10175750', '713364992981']
# ['005930', '20220317', '71200', '71200', '71800', '70900', '17646316', '1258698481050']
# ['005930', '20220318', '70700', '70600', '70900', '70200', '14410038', '1017183110700']
# ['005930', '20220321', '69900', '70900', '71000', '69900', '11169002', '784175429300']
# ['005930', '20220322', '70300', '69900', '70500', '69900', '9402666', '660385691100']
# ['005930', '20220323', '70500', '70600', '71200', '70300', '12398025', '875833161100']
# ['005930', '20220324', '69800', '69600', '70300', '69600', '37943356', '2628885553700']
# ['005930', '20220325', '69800', '70100', '70200', '69600', '12986010', '906006321000']
# ['005930', '20220328', '69700', '69500', '69900', '69200', '12619289', '878172199900']
# ['005930', '20220329', '70200', '70000', '70300', '69800', '13686208', '958589509700']
# ['005930', '20220330', '69900', '70300', '70500', '69800', '12670187', '887514318650']
# ['005930', '20220331', '69600', '69900', '70200', '69600', '12510366', '873212583300']
# ['005930', '20220401', '69100', '69500', '69500', '69000', '15916846', '1100422376400']
# ['005930', '20220404', '69300', '68900', '69300', '68600', '11107905', '766930294459']
# ['005930', '20220405', '69200', '69400', '69600', '69100', '8467248', '586498194900']
# ['005930', '20220406', '68500', '68600', '68800', '68500', '15517308', '1064606110092']
# ['005930', '20220407', '68000', '68500', '68500', '68000', '20683328', '1409872624700']
# ['005930', '20220408', '67800', '68100', '68300', '67700', '15453191', '1050375034852']
# ['005930', '20220411', '67900', '67800', '68100', '67400', '12263735', '831094572700']
# ['005930', '20220412', '67000', '67600', '67700', '67000', '13924389', '936611863500']
# ['005930', '20220413', '68700', '67300', '69000', '67200', '17378620', '1183210424500']
# ['005930', '20220414', '67500', '68700', '68700', '67500', '16409494', '1112667612000']
# ['005930', '20220415', '66600', '67200', '67300', '66500', '13176415', '878858388800']
# ['005930', '20220418', '66700', '66500', '67100', '66100', '10119203', '675310095100']
# ['005930', '20220419', '67300', '67100', '68000', '67000', '12959434', '876087930051']
# ['005930', '20220420', '67400', '67000', '67400', '66500', '16693293', '1116160503800']
# ['005930', '20220421', '67700', '67600', '68300', '67500', '12847448', '872983300180']
# ['005930', '20220422', '67000', '67200', '67300', '66700', '11791478', '789392306300']
# ['005930', '20220425', '66300', '66500', '66700', '66300', '11016474', '731676244400']
# ['005930', '20220426', '66100', '66400', '66700', '66100', '12946923', '858461258448']
# ['005930', '20220427', '65000', '65400', '65500', '64900', '18122084', '1179918512650']
# ['005930', '20220428', '64800', '65400', '65500', '64500', '16895528', '1094277578880']
# ['005930', '20220429', '67400', '65100', '67600', '65000', '26190390', '1747030218800']
# ['005930', '20220502', '67300', '66600', '67600', '66500', '14106184', '946016270200']
# ['005930', '20220503', '67500', '67400', '68400', '67300', '14168875', '962643054300']
# ['005930', '20220504', '67900', '68000', '68400', '67500', '11505248', '781073326235']
# ['005930', '20220506', '66500', '67000', '67100', '66500', '14356156', '957335193600']
# ['005930', '20220509', '66100', '66300', '66900', '66100', '11858736', '787562955000']
# ['005930', '20220510', '65700', '65900', '66300', '65300', '17235604', '1132067708900']
# ['005930', '20220511', '65700', '65500', '66300', '65200', '12330920', '812298026600']
# ['005930', '20220512', '64900', '65200', '65500', '64900', '16414188', '1069685385550']
# ['005930', '20220513', '66500', '65300', '66700', '65200', '14551536', '962476162900']
# ['005930', '20220516', '66300', '67100', '67400', '66100', '11937555', '796060691900']
# ['005930', '20220517', '67600', '66600', '67900', '66600', '15680447', '1058322764800']
# ['005930', '20220518', '68100', '68300', '68700', '67600', '16486319', '1122585202585']
# ['005930', '20220519', '67500', '66500', '67600', '66500', '17073728', '1147743790508']
# ['005930', '20220520', '68000', '67800', '68400', '67700', '12109671', '824048609800']
# ['005930', '20220523', '67900', '68800', '68800', '67600', '13684088', '931341158100']
# ['005930', '20220524', '66500', '67500', '67700', '66500', '15482576', '1035492905500']
# ['005930', '20220525', '66400', '66700', '67100', '65900', '15150490', '1007805029400']
# ['005930', '20220526', '65900', '66300', '67200', '65500', '15970890', '1057298883100']
# ['005930', '20220527', '66500', '66700', '66900', '66200', '11405555', '759034579700']
# ['005930', '20220530', '67700', '67500', '67800', '66900', '14255484', '960592764000']
# ['005930', '20220531', '67400', '67500', '67500', '66700', '24365002', '1637773742750']
# ['005930', '20220602', '66700', '66600', '67000', '66400', '14959443', '996681075588']
# ['005930', '20220603', '66800', '67200', '67300', '66800', '8222883', '550654655700']
# st:2022-02-26, end:2022-06-05
# ['005930', '20220607', '65500', '66200', '66400', '65400', '19355756', '1273444989300']
# ['005930', '20220608', '65300', '65400', '65700', '65300', '12483180', '817379109300']
# ['005930', '20220609', '65200', '65100', '65200', '64500', '25790724', '1673763680952']
# ['005930', '20220610', '63800', '64000', '64400', '63800', '22193552', '1419245099700']
# ['005930', '20220613', '62100', '62400', '62800', '62100', '22157816', '1380636801900']
# ['005930', '20220614', '61900', '61200', '62200', '61100', '24606420', '1519195265000']
# ['005930', '20220615', '60700', '61300', '61500', '60200', '26811224', '1630190882434']
# ['005930', '20220616', '60900', '61300', '61800', '60500', '23394896', '1431052309321']
# ['005930', '20220617', '59800', '59400', '59900', '59400', '29053450', '1732449618748']
# ['005930', '20220620', '58700', '59800', '59900', '58100', '34111304', '1997076972175']
# ['005930', '20220621', '58500', '58700', '59200', '58200', '25148108', '1474998298400']
# ['005930', '20220622', '57600', '59000', '59100', '57600', '23334688', '1360076149300']
# ['005930', '20220623', '57400', '57700', '58000', '56800', '28338608', '1627019443340']
# ['005930', '20220624', '58400', '57900', '59100', '57700', '23256104', '1359292776100']
# ['005930', '20220627', '58800', '59000', '59900', '58300', '18122236', '1071186745402']
# ['005930', '20220628', '59400', '59200', '59500', '58700', '13540538', '800041009700']
# ['005930', '20220629', '58000', '58500', '58800', '58000', '14677138', '855770425874']
# ['005930', '20220630', '57000', '57200', '57600', '57000', '18915142', '1082799462452']
# ['005930', '20220701', '56200', '56900', '57500', '55900', '24982096', '1412473217495']
# ['005930', '20220704', '57100', '56100', '57400', '55700', '17807126', '1012586831300']
# ['005930', '20220705', '57200', '57600', '58200', '57200', '14216539', '818079785900']
# ['005930', '20220706', '56400', '57300', '57300', '56400', '16820460', '955957046500']
# ['005930', '20220707', '58200', '56400', '58700', '56300', '21322832', '1234677644065']
# ['005930', '20220708', '58700', '58600', '59300', '58200', '15339271', '902198939736']
# ['005930', '20220711', '58800', '59300', '59600', '58700', '13042624', '771042671500']
# ['005930', '20220712', '58100', '58600', '58700', '58100', '9336061', '544403361000']
# ['005930', '20220713', '58000', '58300', '58600', '58000', '10841315', '631711977700']
# ['005930', '20220714', '57500', '57500', '58200', '57400', '15067012', '869131233435']
# ['005930', '20220715', '60000', '58400', '60000', '58100', '18685584', '1104045143300']
# ['005930', '20220718', '61900', '60600', '62000', '60500', '20832516', '1277727157981']
# ['005930', '20220719', '60900', '61400', '61500', '60200', '15248261', '925919721166']
# ['005930', '20220720', '60500', '61800', '62100', '60500', '16782238', '1025939109200']
# ['005930', '20220721', '61800', '61100', '61900', '60700', '12291374', '754854999650']
# ['005930', '20220722', '61300', '61800', '62200', '61200', '10261310', '631872940300']
# ['005930', '20220725', '61100', '60900', '61900', '60800', '9193681', '565540190900']
# ['005930', '20220726', '61700', '60800', '61900', '60800', '6597211', '405310045900']
# ['005930', '20220727', '61800', '61300', '61900', '61200', '7320997', '449989960800']
# ['005930', '20220728', '61900', '62300', '62600', '61600', '10745302', '667085256100']
# ['005930', '20220729', '61400', '62400', '62600', '61300', '15093120', '932917972000']
# ['005930', '20220801', '61300', '61000', '61700', '60300', '13154816', '803034710500']
# ['005930', '20220802', '61700', '61200', '61900', '61000', '13614895', '837567187000']
# ['005930', '20220803', '61300', '61600', '61600', '61000', '10053861', '615480978400']
# ['005930', '20220804', '61500', '61700', '61800', '61200', '9125439', '561835808800']
# ['005930', '20220805', '61500', '61700', '61900', '61200', '9567620', '588582544800']
# ['005930', '20220808', '60800', '61400', '61400', '60600', '11313150', '689020306900']
# ['005930', '20220809', '60000', '60600', '60700', '59600', '18251170', '1094260322600']
# ['005930', '20220810', '59100', '58900', '59200', '58600', '18084348', '1065592854894']
# ['005930', '20220811', '59900', '59600', '60000', '59300', '15141941', '903738904000']
# ['005930', '20220812', '60200', '59500', '60700', '59400', '10786658', '648793200100']
# ['005930', '20220816', '61000', '60500', '61600', '60300', '15036727', '917516142200']
# ['005930', '20220817', '60400', '61100', '61200', '60300', '9061518', '550059085700']
# ['005930', '20220818', '61500', '60300', '61900', '60000', '16372754', '997986949000']
# ['005930', '20220819', '60900', '61400', '61600', '60600', '6923679', '421908759900']
# ['005930', '20220822', '60000', '60300', '60400', '59800', '8259865', '495732266100']
# ['005930', '20220823', '59100', '59000', '59600', '59000', '9041629', '535657353300']
# ['005930', '20220824', '59000', '59200', '59500', '59000', '8888486', '525406965200']
# ['005930', '20220825', '59700', '59200', '59700', '59000', '5767902', '342780937200']
# ['005930', '20220826', '60000', '60300', '60900', '59900', '9499995', '573040309950']
# ['005930', '20220829', '58600', '58700', '58900', '58600', '9841329', '577684200900']
# ['005930', '20220830', '58800', '58700', '59000', '58300', '9690044', '567627668500']
# ['005930', '20220831', '59700', '58200', '59900', '58200', '14203512', '841319635900']
# ['005930', '20220901', '58400', '58700', '58900', '58300', '14905777', '872374620601']
# ['005930', '20220902', '57500', '58300', '58600', '57500', '15040310', '872040367551']
# ['005930', '20220905', '57100', '57400', '57800', '56800', '11425977', '653884056584']
# ['005930', '20220906', '57100', '57200', '57600', '56900', '7503086', '429152038700']
# ['005930', '20220907', '56000', '56700', '56700', '55900', '17384854', '975695179700']
# ['005930', '20220908', '55600', '56200', '56400', '55600', '18000016', '1006366398000']
# ['005930', '20220913', '58100', '57000', '58500', '56800', '17166580', '991015891355']
# st:2022-06-06, end:2022-09-13
# ['005930', '20220914', '56800', '56200', '57200', '56100', '12524961', '709906007000']
# ['005930', '20220915', '56000', '57000', '57100', '56000', '11664819', '657641711500']
# ['005930', '20220916', '56200', '55600', '56400', '55500', '13456503', '752455682838']
# ['005930', '20220919', '56400', '56300', '57000', '56000', '12278653', '693636680000']
# ['005930', '20220920', '55800', '56400', '57000', '55800', '14041465', '788331519815']
# ['005930', '20220921', '55300', '55400', '55500', '55000', '11863700', '655017421100']
# ['005930', '20220922', '54400', '54600', '54700', '54300', '12786510', '696058101600']
# ['005930', '20220923', '54500', '54400', '54900', '54200', '10555964', '575503622100']
# ['005930', '20220926', '53900', '53700', '54200', '53600', '15008449', '807353273300']
# ['005930', '20220927', '54200', '53800', '54200', '53500', '16631289', '897144417709']
# ['005930', '20220928', '52900', '53900', '54400', '52500', '19991128', '1064665579214']
# ['005930', '20220929', '52600', '53300', '53700', '52600', '13882080', '737730681500']
# ['005930', '20220930', '53100', '52300', '53600', '51800', '22503248', '1187343660500']
# ['005930', '20221004', '55200', '55300', '55400', '54500', '19148436', '1056852669700']
# ['005930', '20221005', '56000', '56900', '57200', '55400', '22458970', '1261934048318']
# ['005930', '20221006', '56300', '56700', '57300', '56300', '14944446', '848081763100']
# ['005930', '20221007', '56200', '55900', '56900', '55200', '16886812', '949027146468']
# ['005930', '20221011', '55400', '54400', '55700', '54000', '21437876', '1172168853325']
# ['005930', '20221012', '55800', '55700', '57000', '55200', '18408910', '1032656163200']
# ['005930', '20221013', '55200', '55400', '56100', '55200', '13784602', '765435187900']
# ['005930', '20221014', '56300', '56200', '56500', '55800', '12924326', '726962989400']
# ['005930', '20221017', '56600', '55800', '57000', '55700', '13641878', '769638197200']
# ['005930', '20221018', '56500', '56700', '57100', '55800', '14820702', '835744764000']
# ['005930', '20221019', '55800', '56700', '56900', '55700', '12660652', '710947532900']
# ['005930', '20221020', '55500', '55200', '56000', '55100', '17107652', '949265250905']
# ['005930', '20221021', '55900', '55100', '56300', '55100', '11456060', '640343092816']
# ['005930', '20221024', '57500', '57000', '57500', '56700', '16944504', '968892104300']
# ['005930', '20221025', '57700', '57000', '58600', '57000', '17405678', '1009512119302']
# ['005930', '20221026', '59400', '58000', '59600', '57700', '20824968', '1227076491560']
# ['005930', '20221027', '59500', '59700', '60100', '58900', '21756712', '1296030977930']
# ['005930', '20221028', '57300', '58900', '59200', '57200', '20924936', '1213293156195']
# ['005930', '20221031', '59400', '58100', '59900', '58000', '18999514', '1126467842000']
# ['005930', '20221101', '60000', '59900', '60300', '59500', '17201648', '1030380927406']
# ['005930', '20221102', '59600', '59700', '60000', '59300', '13202919', '787057605000']
# ['005930', '20221103', '59200', '58600', '59800', '58100', '17492162', '1029199659366']
# ['005930', '20221104', '59400', '59100', '59500', '58400', '12445841', '734525784600']
# ['005930', '20221107', '60200', '59700', '60300', '59400', '12437246', '747350127100']
# ['005930', '20221108', '61800', '60500', '61900', '60500', '18273898', '1123976801804']
# ['005930', '20221109', '62000', '62000', '62200', '61300', '14045592', '869644724000']
# ['005930', '20221110', '60400', '61400', '61500', '60400', '21087632', '1283005045328']
# ['005930', '20221111', '62900', '63100', '63200', '62300', '20037164', '1257129641861']
# ['005930', '20221114', '61900', '62900', '62900', '61700', '15973416', '993352234080']
# ['005930', '20221115', '62400', '62200', '62500', '61600', '12310986', '764117239743']
# ['005930', '20221116', '62700', '62400', '62700', '61700', '12909260', '804219667250']
# ['005930', '20221117', '61400', '62000', '62000', '61300', '13298296', '819118806800']
# ['005930', '20221118', '61800', '61800', '62400', '61400', '12236503', '757454905470']
# ['005930', '20221121', '61400', '61400', '61800', '60800', '9378097', '573783339409']
# ['005930', '20221122', '60600', '60900', '61200', '60300', '9411289', '571460562800']
# ['005930', '20221123', '61000', '61200', '61300', '60700', '8765050', '534580211500']
# ['005930', '20221124', '61400', '61200', '61700', '60900', '8125010', '497273294550']
# ['005930', '20221125', '61000', '61400', '61700', '60800', '6677933', '407953216200']
# ['005930', '20221128', '60100', '60500', '60500', '59800', '8589032', '515486605100']
# ['005930', '20221129', '60600', '59900', '60600', '59800', '7014160', '422226001673']
# ['005930', '20221130', '62200', '60400', '62200', '60200', '19768904', '1218354958444']
# ['005930', '20221201', '62600', '63100', '63200', '62300', '16631445', '1044546161950']
# ['005930', '20221202', '60400', '62500', '62500', '60400', '15331184', '935960853120']
# ['005930', '20221205', '60300', '60900', '61100', '60000', '13767787', '832613739000']
# ['005930', '20221206', '59200', '59800', '60100', '59200', '13888300', '827339804388']
# ['005930', '20221207', '58900', '58800', '59600', '58500', '12100662', '714083283900']
# ['005930', '20221208', '59200', '58700', '59200', '58600', '12986815', '766212023592']
# ['005930', '20221209', '60400', '59300', '60600', '59300', '10529632', '633777717900']
# ['005930', '20221212', '59500', '59900', '60000', '59400', '9036472', '538557972800']
# ['005930', '20221213', '59700', '59600', '60300', '59400', '9040873', '539587782200']
# ['005930', '20221214', '60500', '59800', '60600', '59800', '8207485', '495209255105']
# ['005930', '20221215', '59300', '59800', '60200', '59300', '8716039', '519762171147']
# ['005930', '20221216', '59500', '58300', '59500', '58300', '13033596', '769867746731']
# ['005930', '20221219', '59500', '59500', '59900', '59100', '7696187', '457558919300']
# ['005930', '20221220', '58600', '59000', '59100', '58500', '9284761', '545533294130']
# ['005930', '20221221', '58000', '58700', '59100', '58000', '10356971', '603985894600']
# ['005930', '20221222', '59100', '58100', '59100', '58100', '10720630', '628698962726']
# st:2022-09-14, end:2022-12-22
# ['005930', '20221223', '58100', '58200', '58400', '57700', '9829407', '570401785680']

# %%
que.qsize()
# Out:
# 0

# %%
gugu = que.get()
gugu
# Out:
# ['000880', '19920901', '5833', '5833', '5833', '5833', '78896', '4602540']

# %%
code = result['output1']['stck_shrn_iscd']
date = result['output2'][0]['stck_bsop_date']
clpr = result['output2'][0]['stck_clpr']
oppr = result['output2'][0]['stck_oprc']
hgpr = result['output2'][0]['stck_hgpr']
lwpr = result['output2'][0]['stck_lwpr']
volume = result['output2'][0]['acml_vol']
acpr = result['output2'][0]['acml_tr_pbmn']

# %%
date_to_string(date=datetime.date(2020, 7, 18))
# Out:
# '20200718'

# %%
datetime.date(2020, 7, 20) > datetime.date(2020, 7, 19)
# Out:
# True

# %%
datetime.date(2020, 7, 18) + datetime.timedelta(100)
# Out:
# datetime.date(2020, 10, 26)

# %%
result = sc.date_price(no='084010', start='20051031', end='20051031', period='D')

# %%
result
# Out:
# {'output1': {'prdy_vrss': '300',
#   'prdy_vrss_sign': '2',
#   'prdy_ctrt': '0.49',
#   'stck_prdy_clpr': '61500',
#   'acml_vol': '9646327',
#   'acml_tr_pbmn': '595372614900',
#   'hts_kor_isnm': '삼성전자',
#   'stck_prpr': '61800',
#   'stck_shrn_iscd': '005930',
#   'prdy_vol': '12808490',
#   'stck_mxpr': '79900',
#   'stck_llam': '43100',
#   'stck_oprc': '62100',
#   'stck_hgpr': '62300',
#   'stck_lwpr': '61100',
#   'stck_prdy_oprc': '60500',
#   'stck_prdy_hgpr': '61500',
#   'stck_prdy_lwpr': '60400',
#   'askp': '61800',
#   'bidp': '61700',
#   'prdy_vrss_vol': '-3162163',
#   'vol_tnrt': '0.16',
#   'stck_fcam': '100',
#   'lstn_stcn': '5969782550',
#   'cpfn': '7780',
#   'hts_avls': '3689326',
#   'per': '10.70',
#   'eps': '5777.00',
#   'pbr': '1.42',
#   'itewhol_loan_rmnd_ratem name': '0.10'},
#  'output2': [{},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {}],
#  'rt_cd': '0',
#  'msg_cd': 'MCA00000',
#  'msg1': '정상처리 되었습니다.'}

# %%
import pandas as pd

# %%
import pymysql

# %%
conn = pymysql.connect(host='localhost', user='root', 
                       password='sp_1234', db='db_for_test', charset='utf8')

# %%
cur = conn.cursor()

# %%
cur.execute(f'INSERT INTO test VALUES({code}, {date}, {clpr}, {oppr}, {hgpr}, {lwpr}, {volume}, {acpr})')
# Out:
# 1

# %%
conn.commit()

# %%
u = [{},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {},
  {}]

# %%
# Out:
# --------------------------------------------------------------------
# TypeError                          Traceback (most recent call last)
# Cell In[280], line 1
# ----> 1 set(u)
#
# TypeError: unhashable type: 'dict'
