# %% [markdown]
# #### Backtest code를 직접구현.

# %% [markdown]
# #### 기능명세 (Proto Type)
# 1. Market timing
# 2. 당일 거래량 상위종목 search (시장에 관심을 받는 종목)
# 3. 상위종목 중 이동평균선 정배열인 종목 search
# 4. 비중 분할 (단순비중 or 확률기반 가중치)
# 5. 손절라인설정

# %% [markdown]
# #### 1. Market timing
# * 코스피 지수 종가가 ma 20 이상일 때만 매매전략 발동

# %%
import pandas as pd 
import matplotlib.pyplot as plt 

class MarketTimming():
    def df_pre(df,start,end):
        df['Date'] = pd.to_datetime(df['Date'])
        df = df[(df['Date'] >= start )&(df['Date']<=end)]
        df = df.set_index('Date')
        df['sma20'] = df['Close'].rolling(20).mean()
        df = df.dropna()
        df['timming'] = df['Close']>df['sma20']
        return df

# %%
dd = MarketTimming()

# %%
df_kospi_raw = pd.read_csv('kospi_test.csv', index_col = 0)

# %%
dd.df_pre(df_kospi_raw,'2019-01-01')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 dd.df_pre(df_kospi_raw,'2019-01-01')
#
# Cell In[59], line 6, in MarketTimming.df_pre(df, start, end)
#       5 def df_pre(df,start,end):
# ----> 6     df['Date'] = pd.to_datetime(df['Date'])
#       7     df = df[(df['Date'] >= start )&(df['Date']<=end)]
#       8     df = df.set_index('Date')
#
# TypeError: 'MarketTimming' object is not subscriptable

# %%
# 전처리함수
def df_pre(df,start, end):
    df['Date'] = pd.to_datetime(df['Date'])
    df = df[(df['Date'] >= start )&(df['Date']<=end)]
    df = df.set_index('Date')
    df['sma20'] = df['Close'].rolling(20).mean()
    df = df.dropna()
    df['timming'] = df['Close']>df['sma20']
    return df

# %%
# 그래프함수
def back_plot(df):
    import matplotlib.pyplot as plt
    from matplotlib import dates
    plt.figure(figsize = (50, 10))
    plt.title("Kospi sma 20 ")
    plt.plot(df["Close"])
    plt.plot(df['sma20'])
    plt.scatter(df.loc[df['timming']==1].index, df['Close'][df['timming']==1],
                color = 'red',
                label='Go',
                marker ='^',
                alpha=0.8)
    plt.scatter(df.loc[df['timming']==0].index, df['Close'][df['timming']==0],
                color = 'blue',
                label='Stop',
                marker ='^',
                alpha=0.8)
    plt.xticks(rotation=45)
    plt.legend()
    plt.show()

# %%
import pandas as pd

# %%
# Data Load
df_kospi_raw = pd.read_csv('kospi_test.csv', index_col = 0)

# %%
# Data PreProcessing
df_kospi = df_pre(df_kospi_raw,'2015-01-01','2019-01-01')

# %%
# Data Graph
back_plot(df_kospi)

# %%
df_kospi_mt = df_pre(df_kospi_raw,'2013-01-01','2022-12-31')

# %%
df_kospi_mt
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-01-29  1946.109985  1958.880005  1944.810059  1955.959961  1955.959961
# 2013-01-30  1961.920044  1967.290039  1950.670044  1964.430054  1964.430054
# 2013-01-31  1960.780029  1965.920044  1954.530029  1961.939941  1961.939941
# 2013-02-01  1964.750000  1966.540039  1942.439941  1957.790039  1957.790039
# 2013-02-04  1968.949951  1969.130005  1952.829956  1953.209961  1953.209961
# ...                 ...          ...          ...          ...          ...
# 2022-12-23  2325.860107  2333.080078  2311.899902  2313.689941  2313.689941
# 2022-12-26  2312.540039  2321.919922  2304.199951  2317.139893  2317.139893
# 2022-12-27  2327.520020  2335.989990  2321.479980  2332.790039  2332.790039
# 2022-12-28  2296.449951  2296.449951  2276.899902  2280.449951  2280.449951
# 2022-12-29  2265.729980  2272.669922  2236.379883  2236.399902  2236.399902
#
#             Volume        sma20  timming
# Date
# 2013-01-29  465000  1988.394995    False
# 2013-01-30  523300  1985.061499    False
# 2013-01-31  399600  1982.187994    False
# 2013-02-01  385900  1979.480499    False
# 2013-02-04  345400  1976.578497    False
# ...            ...          ...      ...
# 2022-12-23  367000  2386.713000    False
# 2022-12-26  427600  2382.156494    False
# 2022-12-27  448300  2377.126501    False
# 2022-12-28  405700  2367.522498    False
# 2022-12-29  361000  2355.350488    False
#
# [2438 rows x 8 columns]

# %%
if df_kospi_mt >=True:
    start model

# %% [markdown]
# #### 2. 당일 거래량 상위종목 (추후 거래대금으로 바뀔수도) Search

# %% [markdown]
# * 날짜별로
# * 전일대비 거래량 증가 하는종목 search

# %%
df_vol_search = pd.read_csv('C:\\Users\\smleo\\Desktop\\Ai\\PJT_Area\\4_SRC\\kospi200_raw.csv', index_col=0)

# %%
# 전일대비 거래량 Db 등록필요 predy_vrss_vol
df_vol_search['전일대비거래량상승률'] = round((df_vol_search['누적거래량'] - df_vol_search['누적거래량'].shift(1)) / df_vol_search['누적거래량'].shift(1) * 100,2)

# %%
# 전일대비 종가대비 증가율 db 등록필요 
df_vol_search['전일대비주가상승률'] = round((df_vol_search['종가'] - df_vol_search['종가'].shift(1)) / df_vol_search['종가'].shift(1) * 100,2)

# %%
df_vol_search.head(5)
# Out:
#             날짜        종가        시가       최고가       최저가    누적거래량     종목명  \
# 60  2018-01-02  210500.0  212500.0  212500.0  208500.0  43076.0  BGF리테일
# 59  2018-01-03  202500.0  205500.0  208500.0  201500.0  39089.0  BGF리테일
# 58  2018-01-04  200500.0  203000.0  203500.0  200500.0  49743.0  BGF리테일
# 57  2018-01-05  200000.0  202500.0  202500.0  196500.0  29452.0  BGF리테일
# 56  2018-01-08  199000.0  200000.0  201000.0  199000.0  26055.0  BGF리테일
#
#     전일대비거래량상승률  전일대비주가상승률
# 60         NaN        NaN
# 59       -9.26      -3.80
# 58       27.26      -0.99
# 57      -40.79      -0.25
# 56      -11.53      -0.50

# %%
df_vol_search[df_vol_search['날짜']=='2018-01-03'].sort_values(by='전일대비거래량상승률', ascending=False)
# Out:
#             날짜        종가        시가       최고가       최저가       누적거래량        종목명  \
# 59  2018-01-03    5320.0    4545.0    5690.0    4505.0  22194916.0      금호타이어
# 59  2018-01-03   41666.0   39666.0   41666.0   37999.0    172958.0       KG스틸
# 59  2018-01-03   15000.0   15200.0   15400.0   14800.0    120191.0    메리츠금융지주
# 59  2018-01-03    8540.0    8060.0    8880.0    7960.0   2617845.0       신풍제약
# 59  2018-01-03   69400.0   68000.0   69500.0   67000.0    846812.0       롯데지주
# ..         ...       ...       ...       ...       ...         ...        ...
# 59  2018-01-03   31950.0   31800.0   32350.0   31550.0    922887.0       강원랜드
# 59  2018-01-03    7726.0    7709.0    7794.0    7616.0   1586303.0  현대두산인프라코어
# 59  2018-01-03  118500.0  118500.0  119000.0  118000.0     22067.0      현대홈쇼핑
# 59  2018-01-03   23180.0   23310.0   23440.0   23051.0    767101.0       대한항공
# 59  2018-01-03    4790.0    5030.0    5040.0    4730.0   9789137.0        HMM
#
#     전일대비거래량상승률  전일대비주가상승률
# 59     1057.72      19.02
# 59      681.06      29.67
# 59      639.05      -2.28
# 59      482.28       7.42
# 59      421.57       5.95
# ..         ...        ...
# 59      -54.14      -0.31
# 59      -55.51       0.55
# 59      -58.53      -0.42
# 59      -63.43      -0.42
# 59      -71.38      -4.39
#
# [174 rows x 9 columns]

# %% [markdown]
# ### 가설검증

# %% [markdown]
# * 전일대비 거래량 급등 = 주가 급락, 급등 모두 가능성을 가지고 있음
# * 검증해볼만한 점 : 거래량 급등은 급락, 급등 중 어느쪽이 확률이 높은가? 어느쪽이 상승률이높은가? 등

# %% [markdown]
# #### Hypotheses 1
# 가설 : 당일 거래량이 전일대비 상승했으면 당일 주가가 상승했었을 확률이 높다.
# Data 수 : 216,830
# 범위 : Kospi200 5년치 Data
#
# 전일대비 :
# ( 거래상승률 + ) = 102,621
# ( 거래상승률 + ) & ( 주가상승률 + ) = 53,643
#
# 확률 : 52.27 %

# %%
con_1 = df_vol_search['전일대비거래량상승률'] >=0
con_2 = df_vol_search['전일대비주가상승률'] >=0

# %%
a = df_vol_search.loc[(con_1)].shape[0]
b = df_vol_search.loc[(con_1)&(con_2)].shape[0]
print(a,b)
print(round((b/a)*100,2),'%')
# Out:
# 102621 53643
# 52.27 %

# %% [markdown]
# #### Hypotheses 2
# 가설 : 당일 거래량이 전일대비 상승했으면 다음날 주가가 상승할 확률이 높다.
# Data 수 : 216,830
# 범위 : Kospi200 5년치 Data
#
# 전일대비 :
# ( 거래상승률 + ) = 102,621
# ( 거래상승률 + ) & ( 주가상승률 + ) = 52,607
#
# 확률 : 51.26 %

# %%
con_1 = df_vol_search['전일대비거래량상승률'] >=0
con_2 = df_vol_search['전일대비주가상승률'].shift(-1) >=0

# %%
a = df_vol_search.loc[(con_1)].shape[0]
b = df_vol_search.loc[(con_1)&(con_2)].shape[0]
print(a,b)
print(round((b/a)*100,2),'%')
# Out:
# 102621 52607
# 51.26 %

# %% [markdown]
# #### Result
# 거래량 중요한 지표이지만 위 검증은 단순검증에 Data 도 적음
# 중요한건 거래량변화가 어떤 패턴을 보일 때 진입해야 수익을 낼 수 있는지임
# 우선 거래량 search 는 다양한 퀀트 전략을 참조 할 예정

# %% [markdown]
#  단순전략 :  거래량 증가율 상위 50종목 search

# %%
def vol_search(df,date,count):
    df_result = df[df['날짜']==date].sort_values(by='전일대비거래량상승률', ascending=False)[:count]
    return df_result

# %%
vol_search(df_vol_search,'2022-12-01',50)
# Out:
#             날짜        종가        시가       최고가       최저가      누적거래량  \
# 20  2022-12-01  153500.0  153000.0  160000.0  149000.0   133867.0
# 20  2022-12-01   24000.0   21750.0   25000.0   21750.0  3529276.0
# 20  2022-12-01   54800.0   52500.0   55000.0   51900.0   276790.0
# 20  2022-12-01   92600.0   98400.0   98400.0   91500.0   240011.0
# 20  2022-12-01   25000.0   24400.0   25150.0   24200.0   266277.0
# 20  2022-12-01   20850.0   20750.0   21700.0   20350.0    98699.0
# 20  2022-12-01   94000.0   93400.0   95000.0   93000.0    95360.0
# 20  2022-12-01   34050.0   34150.0   35150.0   34050.0    84817.0
# 20  2022-12-01  241000.0  241000.0  242000.0  239000.0    70221.0
# 20  2022-12-01    5420.0    5470.0    5480.0    5260.0  2655580.0
# 20  2022-12-01  213000.0  212500.0  216000.0  211500.0    87477.0
# 20  2022-12-01   46850.0   47300.0   47500.0   46700.0    45007.0
# 20  2022-12-01   27900.0   28500.0   28550.0   27850.0   183527.0
# 20  2022-12-01   57900.0   59200.0   59600.0   57700.0  2895695.0
# 20  2022-12-01   14450.0   14350.0   14700.0   14300.0   101772.0
# 20  2022-12-01   13500.0   13550.0   13650.0   13400.0   900058.0
# 20  2022-12-01   19150.0   19300.0   19550.0   19100.0   227058.0
# 20  2022-12-01   39900.0   39200.0   40200.0   39050.0   123596.0
# 20  2022-12-01    9600.0    9560.0    9690.0    9500.0   202972.0
# 20  2022-12-01   56600.0   58300.0   58300.0   56300.0   152030.0
# 20  2022-12-01  187500.0  194500.0  195000.0  187500.0  1218297.0
# 20  2022-12-01   84400.0   85200.0   85800.0   84300.0    72503.0
# 20  2022-12-01   46500.0   46700.0   46900.0   46250.0   107218.0
# 20  2022-12-01  211000.0  213000.0  214000.0  208000.0    77890.0
# 20  2022-12-01   62100.0   62900.0   63500.0   62100.0    70356.0
# 20  2022-12-01    1695.0    1715.0    1740.0    1690.0  7170802.0
# 20  2022-12-01   26350.0   26300.0   26550.0   26250.0   167681.0
# 20  2022-12-01   46050.0   45800.0   46250.0   45500.0   649362.0
# 20  2022-12-01   95600.0   96400.0   97400.0   95200.0   323366.0
# 20  2022-12-01   30050.0   29800.0   30150.0   29700.0   113160.0
# 20  2022-12-01   41100.0   41250.0   42100.0   41000.0   632694.0
# 20  2022-12-01   74200.0   73600.0   74900.0   73000.0   323573.0
# 20  2022-12-01   91500.0   92700.0   93200.0   91200.0   174757.0
# 20  2022-12-01  158500.0  163500.0  165500.0  157500.0    51949.0
# 20  2022-12-01   72300.0   75800.0   75800.0   71800.0   194392.0
# 20  2022-12-01   61000.0   61400.0   62300.0   60800.0   181024.0
# 20  2022-12-01   41900.0   41400.0   42850.0   41100.0   332025.0
# 20  2022-12-01   32400.0   32400.0   33050.0   32250.0    66757.0
# 20  2022-12-01   13950.0   13900.0   14000.0   13700.0   415021.0
# 20  2022-12-01   63300.0   62900.0   63500.0   62100.0   263909.0
# 20  2022-12-01    3040.0    3040.0    3080.0    3015.0   271697.0
# 20  2022-12-01  760000.0  775000.0  777000.0  754000.0     6574.0
# 20  2022-12-01   21800.0   21500.0   21900.0   21500.0    35066.0
# 20  2022-12-01    6070.0    5970.0    6070.0    5970.0   482416.0
# 20  2022-12-01   82398.0   81157.0   82494.0   80584.0    15404.0
# 20  2022-12-01   15650.0   15300.0   15650.0   15300.0    84152.0
# 20  2022-12-01   47750.0   47900.0   48200.0   47450.0    76745.0
# 20  2022-12-01   31120.0   31071.0   31611.0   30924.0    60182.0
# 20  2022-12-01   33550.0   33350.0   33750.0   33050.0   162295.0
# 20  2022-12-01  128000.0  132500.0  133500.0  126500.0   451577.0
#
#             종목명  전일대비거래량상승률  전일대비주가상승률
# 20         대웅제약      726.54       4.07
# 20         신풍제약      366.81      10.85
# 20         하나투어      248.11       6.61
# 20           두산      182.07      -4.83
# 20     신세계인터내셔날      131.98       3.52
# 20           대웅      124.15       2.71
# 20         키움증권      110.92       2.17
# 20       아이에스동서       95.02      -0.29
# 20          KCC       78.67       1.05
# 20          팬오션       74.63       0.56
# 20          신세계       64.89       1.19
# 20         동원산업       64.64      -0.43
# 20          에스엘       64.48       0.00
# 20          카카오       58.59       2.66
# 20      한올바이오파마       55.45       1.40
# 20           후성       54.42       1.89
# 20       대우조선해양       53.82       0.26
# 20         한국콜마       52.86       2.97
# 20     화승엔터프라이즈       47.04       2.45
# 20  LS ELECTRIC       41.94      -1.91
# 20        NAVER       38.39       0.27
# 20         롯데쇼핑       36.19      -0.12
# 20        코오롱인더       35.75       1.31
# 20        한솔케미칼       34.30       0.48
# 20       롯데정밀화학       34.19      -0.64
# 20         대한전선       32.60       0.30
# 20        하이트진로       29.64       0.76
# 20        DB하이텍       28.11       3.25
# 20          OCI       27.51       0.53
# 20       현대엘리베이       22.95       0.84
# 20         현대건설       20.21       0.24
# 20         호텔신라       19.40       1.64
# 20       LIG넥스원       17.27      -1.08
# 20         대한유화       16.87      -1.86
# 20           LS       13.75      -3.86
# 20         한전기술       11.72       0.66
# 20      LX인터내셔널       11.39       1.70
# 20       PI첨단소재       10.85       0.93
# 20         동국제강        9.84       1.45
# 20      일진머티리얼즈        8.62       2.26
# 20        금호타이어        8.44       1.00
# 20           영풍        8.14      -0.65
# 20           동서        7.60       1.87
# 20        쌍용C&E        6.27       1.68
# 20          종근당        4.93       3.11
# 20       오리온홀딩스        4.58       2.29
# 20         영원무역        3.16       0.53
# 20       한미사이언스        2.74       0.96
# 20        휠라홀딩스        2.68       1.51
# 20       아모레퍼시픽        1.93      -1.92
